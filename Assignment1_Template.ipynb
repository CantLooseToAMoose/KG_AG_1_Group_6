# %% [markdown]
# # 📘 KG course SPARQL notebook
#
# A notebook to run SPARQL queries for the KG course at UM DACS.
#
# 1. Update the `g.parse()` calls in the first cell to import your RDF files.
# 2. In the same folder as the notebook create files with your SPARQL queries (e.g. `q1.rq`), and execute them with `run_query(g, 'q1.rq')`
#
# Use the `.rq` file extension to get SPARQL syntax coloration

# %%
import sys
# !{sys.executable} -m pip install pandas oxrdflib Pygments

import pandas as pd
from IPython.display import display, HTML
from pygments import highlight
from pygments.lexers import SparqlLexer
from pygments.formatters import HtmlFormatter
from rdflib import Graph

def run_query(graph, query_path):
    try:
        with open(query_path, 'r') as file:
            query = file.read()
    except Exception as _e:
        print(f"No file for {query_path}")
        return
    results = graph.query(query)
    # Display the SPARQL query
    formatted_query = highlight(query, SparqlLexer(), HtmlFormatter(style='solarized-dark', full=True, nobackground=True))
    display(HTML(formatted_query))
    # Convert results to a Pandas DataFrame
    res_list = []
    for row in results:
        res_list.append([str(item) for item in row])
    df = pd.DataFrame(res_list, columns=[str(var) for var in results.vars]) if len(res_list) > 0 else pd.DataFrame()
    # Display the DataFrame as a table in Jupyter Notebook
    display(HTML(df.to_html()))

g = Graph(store="Oxigraph")

# TODO: modify/add paths to your RDF files
g.parse("enriched_with_ingredient_mentions_plus_entity_link.ttl")
# g.parse("./climate_kg.ttl")

print(f"Working with {len(g)} triples")
# Out:
# Requirement already satisfied: pandas in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Collecting oxrdflib
#   Downloading oxrdflib-0.4.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: Pygments in c:\users\ariesenihw\appdata\roaming\python\python310\site-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ariesenihw\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: rdflib<8.0,>=6.3 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from oxrdflib) (7.1.3)
# Collecting pyoxigraph~=0.4.2
#   Downloading pyoxigraph-0.4.8-cp38-abi3-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\ariesenihw\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: isodate<1.0.0,>=0.7.2 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from rdflib<8.0,>=6.3->oxrdflib) (0.7.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\ariesenihw\appdata\local\programs\python\python310\lib\site-packages (from rdflib<8.0,>=6.3->oxrdflib) (3.2.0)
# Installing collected packages: pyoxigraph, oxrdflib
# Successfully installed oxrdflib-0.4.0 pyoxigraph-0.4.8
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Working with 602870 triples

# %% [markdown]
# 1. Find recipes that are risky for individuals allergic to mango.

# %%
run_query(g, 'q1.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>   <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span>  <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
#
# <span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?recipe</span> <span class="nv">?recipeName</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">name</span> <span class="nv">?recipeName</span> <span class="p">;</span>
#           <span class="nn">ex</span><span class="p">:</span><span class="nt">containsIngredient</span> <span class="nv">?ingredient</span> <span class="p">.</span>
#   <span class="nv">?ingredient</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?ingredientLabel</span> <span class="p">.</span>
#
#   <span class="c"># Check if &#39;mango&#39; appears in the ingredient label</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nv">?ingredientLabel</span><span class="p">),</span> <span class="s">&quot;mango&quot;</span><span class="p">))</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recipe</th>
#       <th>recipeName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/recipe_99</td>
#       <td>chaat masala</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://kg-course/food-nutrition/recipe_9890</td>
#       <td>raw aam ka guramma</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://kg-course/food-nutrition/recipe_9827</td>
#       <td>mango raita</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://kg-course/food-nutrition/recipe_9767</td>
#       <td>pistachio-crusted pork scaloppine with mango shrimp</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://kg-course/food-nutrition/recipe_9690</td>
#       <td>semolina and coconut dessert</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://kg-course/food-nutrition/recipe_9209</td>
#       <td>mango coconut cucumber salad</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://kg-course/food-nutrition/recipe_9153</td>
#       <td>pudina ki chutney</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://kg-course/food-nutrition/recipe_9098</td>
#       <td>charishma's yummy mango halwa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://kg-course/food-nutrition/recipe_9094</td>
#       <td>children's mango chaat</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://kg-course/food-nutrition/recipe_9035</td>
#       <td>mango daiquiri</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://kg-course/food-nutrition/recipe_8965</td>
#       <td>kadukash ( sindhi mango pickle)</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://kg-course/food-nutrition/recipe_8960</td>
#       <td>mango mousse</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://kg-course/food-nutrition/recipe_8937</td>
#       <td>power smoothies</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://kg-course/food-nutrition/recipe_8897</td>
#       <td>tropical fruit salsa</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://kg-course/food-nutrition/recipe_8714</td>
#       <td>tropical fruit salad with banana cream</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://kg-course/food-nutrition/recipe_8647</td>
#       <td>tropical fruit muffins</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://kg-course/food-nutrition/recipe_8641</td>
#       <td>refreshing thai seafood salad</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://kg-course/food-nutrition/recipe_8571</td>
#       <td>mango pudding</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://kg-course/food-nutrition/recipe_8306</td>
#       <td>banana and mango bread</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://kg-course/food-nutrition/recipe_8026</td>
#       <td>mango cream dip</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://kg-course/food-nutrition/recipe_7950</td>
#       <td>traditional mango chutney</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://kg-course/food-nutrition/recipe_7917</td>
#       <td>southwest smoothie</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://kg-course/food-nutrition/recipe_7807</td>
#       <td>mango salsa</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://kg-course/food-nutrition/recipe_7752</td>
#       <td>fresh fruit frappe</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://kg-course/food-nutrition/recipe_7466</td>
#       <td>pappacito's mango chicken</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://kg-course/food-nutrition/recipe_7086</td>
#       <td>fruited spinach salad with honey mustard dressing</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://kg-course/food-nutrition/recipe_596</td>
#       <td>fruit salsa</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://kg-course/food-nutrition/recipe_5453</td>
#       <td>mango muffins</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://kg-course/food-nutrition/recipe_5405</td>
#       <td>blackened swordfish with tropical fruit salsa</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://kg-course/food-nutrition/recipe_534</td>
#       <td>green mango salad with cilantro vinaigrette</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://kg-course/food-nutrition/recipe_4562</td>
#       <td>cherry pecan carrot layer cake</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://kg-course/food-nutrition/recipe_4507</td>
#       <td>di's mango mousse trifle</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>http://kg-course/food-nutrition/recipe_4445</td>
#       <td>mango madness smoothie</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>http://kg-course/food-nutrition/recipe_3554</td>
#       <td>citrus-rubbed veal chops with sunshine salsa</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>http://kg-course/food-nutrition/recipe_340</td>
#       <td>mango salsa</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>http://kg-course/food-nutrition/recipe_2771</td>
#       <td>murg kari (chicken curry)</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>http://kg-course/food-nutrition/recipe_2750</td>
#       <td>mango chicken</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>http://kg-course/food-nutrition/recipe_2749</td>
#       <td>major greys army chutney</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>http://kg-course/food-nutrition/recipe_2728</td>
#       <td>honey-cheddar-chutney scones</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>http://kg-course/food-nutrition/recipe_2720</td>
#       <td>hawaiian fruit dip</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>http://kg-course/food-nutrition/recipe_2661</td>
#       <td>tropical fruit with lime</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>http://kg-course/food-nutrition/recipe_159</td>
#       <td>chicken curry</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>http://kg-course/food-nutrition/recipe_12688</td>
#       <td>papaya and mango jam</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>http://kg-course/food-nutrition/recipe_11320</td>
#       <td>chicken with mango salsa</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>http://kg-course/food-nutrition/recipe_11213</td>
#       <td>sambuca fruit salad</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>http://kg-course/food-nutrition/recipe_11169</td>
#       <td>prawns with garlic</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>http://kg-course/food-nutrition/recipe_10954</td>
#       <td>mangoes</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>http://kg-course/food-nutrition/recipe_10633</td>
#       <td>avocado-mango salsa</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>http://kg-course/food-nutrition/recipe_10619</td>
#       <td>tropical pina colada shake</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>http://kg-course/food-nutrition/recipe_10550</td>
#       <td>tropical cheesecake</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>http://kg-course/food-nutrition/recipe_10501</td>
#       <td>chicken with curried mango sauce</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>http://kg-course/food-nutrition/recipe_10472</td>
#       <td>fresh salsa (a la gringo)</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>http://kg-course/food-nutrition/recipe_10458</td>
#       <td>tropical sunshine smoothie</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>http://kg-course/food-nutrition/recipe_10416</td>
#       <td>mixed berry smoothie (vegetarian)</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>http://kg-course/food-nutrition/recipe_10175</td>
#       <td>coconut pork and chilli chutney</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>http://kg-course/food-nutrition/recipe_10038</td>
#       <td>mango tokku</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2. List all pies tagged as 'healthy' with a total cooking time of less than 2 hours.

# %%
run_query(g, 'q2.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span> <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>  <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">xsd</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2001/XMLSchema#&gt;</span>
#
# <span class="k">SELECT</span> <span class="nv">?recipe</span> <span class="nv">?recipeName</span> <span class="nv">?prepTime</span> <span class="nv">?cookTime</span> <span class="nv">?sumTimeInMinutes</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">name</span> <span class="nv">?recipeName</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">recipeCategory</span> <span class="nv">?category</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">keywords</span> <span class="nv">?keyword</span> <span class="p">.</span>
#
#   <span class="c"># &quot;pie&quot; in recipeCategory (case-insensitive)</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nv">?category</span><span class="p">),</span> <span class="s">&quot;pie&quot;</span><span class="p">))</span>
#
#   <span class="c"># &quot;healthy&quot; in keywords (case-insensitive)</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nv">?keyword</span><span class="p">),</span> <span class="s">&quot;healthy&quot;</span><span class="p">))</span>
#
#   <span class="c"># We expect these to be xsd:duration (e.g. &quot;PT1H30M&quot;)</span>
#   <span class="k">OPTIONAL</span> <span class="p">{</span> <span class="nv">?recipe</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">cookTime</span> <span class="nv">?cookTime</span> <span class="p">}</span>
#   <span class="k">OPTIONAL</span> <span class="p">{</span> <span class="nv">?recipe</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">prepTime</span> <span class="nv"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recipe</th>
#       <th>recipeName</th>
#       <th>prepTime</th>
#       <th>cookTime</th>
#       <th>sumTimeInMinutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/recipe_9172</td>
#       <td>ritz cracker pecan pie</td>
#       <td>PT15M</td>
#       <td>PT30M</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://kg-course/food-nutrition/recipe_913</td>
#       <td>ritz mock apple pie iii</td>
#       <td>P0D</td>
#       <td>PT25M</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://kg-course/food-nutrition/recipe_8451</td>
#       <td>pumpkin pie</td>
#       <td>PT15M</td>
#       <td>PT50M</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://kg-course/food-nutrition/recipe_8368</td>
#       <td>marions best ever apple pie</td>
#       <td>PT45M</td>
#       <td>PT50M</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://kg-course/food-nutrition/recipe_8342</td>
#       <td>chicken-vegetable pot pie / pies</td>
#       <td>PT30M</td>
#       <td>PT1H</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://kg-course/food-nutrition/recipe_8273</td>
#       <td>marshmallow meringue  apple pie</td>
#       <td>PT15M</td>
#       <td>PT40M</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://kg-course/food-nutrition/recipe_8200</td>
#       <td>rhubarb custard pie</td>
#       <td>PT15M</td>
#       <td>PT1H</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://kg-course/food-nutrition/recipe_8189</td>
#       <td>cranberry mince pie</td>
#       <td>PT15M</td>
#       <td>PT30M</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://kg-course/food-nutrition/recipe_8136</td>
#       <td>apple pie #3</td>
#       <td>PT15M</td>
#       <td>PT35M</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://kg-course/food-nutrition/recipe_7478</td>
#       <td>fresh peach crisp</td>
#       <td>PT30M</td>
#       <td>PT45M</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://kg-course/food-nutrition/recipe_6742</td>
#       <td>old fashioned apple cider pie</td>
#       <td>P0D</td>
#       <td>PT53M</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://kg-course/food-nutrition/recipe_563</td>
#       <td>grape-nuts pie</td>
#       <td>PT25M</td>
#       <td>PT50M</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://kg-course/food-nutrition/recipe_5189</td>
#       <td>diabetic, low-fat pumpkin pie</td>
#       <td>PT20M</td>
#       <td>PT1H</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://kg-course/food-nutrition/recipe_4861</td>
#       <td>cherry pie</td>
#       <td>PT15M</td>
#       <td>PT55M</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://kg-course/food-nutrition/recipe_4817</td>
#       <td>lemon cherry icebox pie</td>
#       <td>PT15M</td>
#       <td>PT1H</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://kg-course/food-nutrition/recipe_45</td>
#       <td>buttermilk pie with gingersnap crumb crust</td>
#       <td>PT30M</td>
#       <td>PT50M</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://kg-course/food-nutrition/recipe_432</td>
#       <td>blue mountain blueberry pie</td>
#       <td>PT45M</td>
#       <td>PT45M</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://kg-course/food-nutrition/recipe_4059</td>
#       <td>low-fat pumpkin pie</td>
#       <td>PT15M</td>
#       <td>PT55M</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://kg-course/food-nutrition/recipe_3904</td>
#       <td>springtime "pine-apple" pie</td>
#       <td>PT20M</td>
#       <td>PT50M</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://kg-course/food-nutrition/recipe_367</td>
#       <td>vinegar pie</td>
#       <td>PT15M</td>
#       <td>PT11M</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://kg-course/food-nutrition/recipe_3577</td>
#       <td>caramel apple pie with crunchy crumb topping</td>
#       <td>PT45M</td>
#       <td>PT55M</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://kg-course/food-nutrition/recipe_3195</td>
#       <td>lemon cranberry pie</td>
#       <td>PT15M</td>
#       <td>PT30M</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://kg-course/food-nutrition/recipe_2844</td>
#       <td>ritz cracker pie</td>
#       <td>PT40M</td>
#       <td>PT40M</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://kg-course/food-nutrition/recipe_2393</td>
#       <td>good ol' pumpkin pie</td>
#       <td>PT30M</td>
#       <td>PT1H</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://kg-course/food-nutrition/recipe_2185</td>
#       <td>blackberry pie</td>
#       <td>PT10M</td>
#       <td>PT45M</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://kg-course/food-nutrition/recipe_2137</td>
#       <td>fresh rhubarb pie</td>
#       <td>P0D</td>
#       <td>PT40M</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://kg-course/food-nutrition/recipe_13156</td>
#       <td>apple pecan cobbler</td>
#       <td>PT15M</td>
#       <td>PT1H</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://kg-course/food-nutrition/recipe_11308</td>
#       <td>candy apple pie</td>
#       <td>PT10M</td>
#       <td>PT1H</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://kg-course/food-nutrition/recipe_1059</td>
#       <td>rice case for quiches or pies (gluten-free)</td>
#       <td>PT10M</td>
#       <td>PT15M</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://kg-course/food-nutrition/recipe_1045</td>
#       <td>raisin cream pie</td>
#       <td>PT30M</td>
#       <td>PT15M</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://kg-course/food-nutrition/recipe_10413</td>
#       <td>sour cherry pie</td>
#       <td>PT10M</td>
#       <td>PT35M</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://kg-course/food-nutrition/recipe_10084</td>
#       <td>5-ingredient strawberry pie</td>
#       <td>PT10M</td>
#       <td>PT5M</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 3. List all restaurants in New Delhi that serve Chinese cuisine and offer online delivery.

# %%
run_query(g, 'q3.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>   <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span>  <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
#
# <span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?restaurant</span> <span class="nv">?restaurantName</span> <span class="nv">?cuisine</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?restaurant</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Restaurant</span> <span class="p">;</span>
#               <span class="nn">sdo</span><span class="p">:</span><span class="nt">legalName</span> <span class="nv">?restaurantName</span> <span class="p">;</span>
#               <span class="nn">sdo</span><span class="p">:</span><span class="nt">areaServed</span> <span class="s">&quot;New Delhi&quot;</span> <span class="p">;</span>  <span class="c"># The city</span>
#               <span class="nn">ex</span><span class="p">:</span><span class="nt">hasDelivery</span> <span class="nv">?delivery</span> <span class="p">;</span>    <span class="c"># true/false</span>
#               <span class="nn">ex</span><span class="p">:</span><span class="nt">hasCuisine</span> <span class="nv">?cuisine</span> <span class="p">.</span>      <span class="c"># Link to Cuisine</span>
#
#   <span class="c"># Must offer online delivery</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nv">?delivery</span> <span class="o">=</span> <span class="kc">true</span><span class="p">)</span>
#
#   <span class="c"># Ensure the cuisine is Chinese (case-insensitive)</span>
#   <span class="nv">?cuisine</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?cuisineLabel</span> <span class="p">.</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nv">?cuisineLabel</span><span class="p">),</span> <span class="s">&quot;chinese&quot;</span><span class="p">))</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant</th>
#       <th>restaurantName</th>
#       <th>cuisine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/restaurant_9980</td>
#       <td>The Food Junction</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://kg-course/food-nutrition/restaurant_9835</td>
#       <td>Samavar</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://kg-course/food-nutrition/restaurant_9803</td>
#       <td>Hari Mirch Masala</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://kg-course/food-nutrition/restaurant_977</td>
#       <td>Chawla Family Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://kg-course/food-nutrition/restaurant_969</td>
#       <td>The Tandoor</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://kg-course/food-nutrition/restaurant_9671</td>
#       <td>Shree Rathnam</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://kg-course/food-nutrition/restaurant_9670</td>
#       <td>Shree Rathnam</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://kg-course/food-nutrition/restaurant_967</td>
#       <td>Grand Plaza</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://kg-course/food-nutrition/restaurant_965</td>
#       <td>Sethi's Restaurant &amp; Barbeque</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://kg-course/food-nutrition/restaurant_9602</td>
#       <td>Chef Joint</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://kg-course/food-nutrition/restaurant_9572</td>
#       <td>Chinese Hut</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://kg-course/food-nutrition/restaurant_9565</td>
#       <td>Flavours of Tibet</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://kg-course/food-nutrition/restaurant_954</td>
#       <td>Karnataka</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://kg-course/food-nutrition/restaurant_948</td>
#       <td>Waves</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://kg-course/food-nutrition/restaurant_9459</td>
#       <td>Gulnar Bar Be Que</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://kg-course/food-nutrition/restaurant_930</td>
#       <td>Zen</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://kg-course/food-nutrition/restaurant_908</td>
#       <td>Dawat Khana</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://kg-course/food-nutrition/restaurant_9050</td>
#       <td>Rain Tree Grill</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://kg-course/food-nutrition/restaurant_905</td>
#       <td>Taste of China</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://kg-course/food-nutrition/restaurant_8959</td>
#       <td>Asian Haus</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://kg-course/food-nutrition/restaurant_8949</td>
#       <td>Prince of China</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://kg-course/food-nutrition/restaurant_8915</td>
#       <td>Puratan - Family Restaurant &amp; Bar</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://kg-course/food-nutrition/restaurant_8883</td>
#       <td>Handi Chhareyan Di</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://kg-course/food-nutrition/restaurant_8872</td>
#       <td>Shri Rama Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://kg-course/food-nutrition/restaurant_8666</td>
#       <td>Singh's Kitchen</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://kg-course/food-nutrition/restaurant_8649</td>
#       <td>Chawla Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://kg-course/food-nutrition/restaurant_8619</td>
#       <td>Mangal Sweets</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://kg-course/food-nutrition/restaurant_824</td>
#       <td>Chimney Sizzlers</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://kg-course/food-nutrition/restaurant_823</td>
#       <td>Al Kuresh</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://kg-course/food-nutrition/restaurant_807</td>
#       <td>Cosy Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://kg-course/food-nutrition/restaurant_803</td>
#       <td>Pindi</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://kg-course/food-nutrition/restaurant_800</td>
#       <td>Chicken Inn</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>http://kg-course/food-nutrition/restaurant_7908</td>
#       <td>Sagar Ratna</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>http://kg-course/food-nutrition/restaurant_7884</td>
#       <td>Food Land</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>http://kg-course/food-nutrition/restaurant_7856</td>
#       <td>Aggarwal Sweet Corner</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>http://kg-course/food-nutrition/restaurant_7851</td>
#       <td>Zaaika Junction</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>http://kg-course/food-nutrition/restaurant_7720</td>
#       <td>Chik Chow</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>http://kg-course/food-nutrition/restaurant_7713</td>
#       <td>Ardor 2.1</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>http://kg-course/food-nutrition/restaurant_771</td>
#       <td>Krips Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>http://kg-course/food-nutrition/restaurant_769</td>
#       <td>Adyar Ananda Bhavan</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>http://kg-course/food-nutrition/restaurant_7679</td>
#       <td>Chit Chat</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>http://kg-course/food-nutrition/restaurant_7661</td>
#       <td>New Ba

# %% [markdown]
# 4. Find the average cost of two dining at restaurants in Davenport that serve Asian food.

# %%
run_query(g, 'q4.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="c">#I tried matching to asian however a lot of davenports only have the country so instead I match on some asian countries and look for asian</span>
# <span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>   <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span>  <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">xsd</span><span class="p">:</span>  <span class="nl">&lt;http://www.w3.org/2001/XMLSchema#&gt;</span>
#
# <span class="k">SELECT</span> <span class="nv">?costString</span> <span class="nv">?name</span> <span class="nv">?cuisine</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?restaurant</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Restaurant</span> <span class="p">;</span>
#               <span class="nn">sdo</span><span class="p">:</span><span class="nt">areaServed</span> <span class="s">&quot;Davenport&quot;</span> <span class="p">;</span>   <span class="c"># City</span>
#               <span class="nn">sdo</span><span class="p">:</span><span class="nt">priceRange</span> <span class="nv">?costString</span> <span class="p">;</span>   <span class="c"># Average cost for two as a string</span>
#               <span class="nn">ex</span><span class="p">:</span><span class="nt">hasCuisine</span> <span class="nv">?cuisine</span> <span class="p">;</span>
#               <span class="nn">schema</span><span class="p">:</span><span class="nt">legalName</span> <span class="nv">?name</span> <span class="p">.</span>
#
#   <span class="nv">?cuisine</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?cuisineLabel</span> <span class="p">.</span>
#
#   <span class="c"># Match any of the listed Asian cuisine labels (case-insensitive):</span>
#   <span class="k">FILTER</span><span class="p">(</span>
#     <span class="nf">LCASE</span><span class="p">(</span><span class="nv">?cuisineLabel</span><span class="p">)</span> <span class="o">=</span> <span class="s">&quot;chinese&quot;</span> <span class="o">||</span>
#     <span class="nf">LCASE</span><span class="p">(</span><span class="nv">?cuisineLabel</span><span class="p">)</span> <span class="o">=</span> <span class="s">&quot;indian&quot;</span> <span class="o">||</span>
#     <span class="nf">LCASE</span><span class="p">(</span><span class="nv">?cuisineLabel</span><span class="p">)</span> <span cla
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>costString</th>
#       <th>name</th>
#       <th>cuisine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.0</td>
#       <td>Olive Tree Cafe</td>
#       <td>http://kg-course/food-nutrition/is_indian</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40.0</td>
#       <td>Osaka</td>
#       <td>http://kg-course/food-nutrition/is_japanese</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25.0</td>
#       <td>Tantra Asian Bistro</td>
#       <td>http://kg-course/food-nutrition/is_asian</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25.0</td>
#       <td>Exotic Thai Restaurant</td>
#       <td>http://kg-course/food-nutrition/is_thai</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>25.0</td>
#       <td>China Cafe</td>
#       <td>http://kg-course/food-nutrition/is_chinese</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 5. Recommend the top 5 desserts published after 2000 that are labeled as ‘Easy’ and low in calories, along with their images.

# %%
run_query(g, 'q5.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="c">#FOR this one we chose not to look for keyword low calorie since we manually inspected our triples and saw zero low calorie </span>
# <span class="c">#mentions so we look for an easy dessert with a low nutrition calorie wise since take for example recipe: ex:recipe_6916 which has in its name</span>
# <span class="c">#low calorie lemonade yet in its keywords we only find easy and vegan this lack of low calorie might be due to the fact we only have a small subset </span>
# <span class="c">#of triples in our graph from the whole df or our preprocessing split the words low calorie which would be odd as it has preserved low cholesterol or low protein for example.</span>
# <span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>    <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span>   <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span>  <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">xsd</span><span class="p">:</span>   <span class="nl">&lt;http://www.w3.org/2001/XMLSchema#&gt;</span>
#
# <span class="k">SELECT</span>
#   <span class="nv">?recipe</span>
#   <span class="nv">?name</span>
#   <span class="nv">?datePublished</span>
#   <span class="nv">?calories</span>
#   <span class="nv">?image</span>
#   <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?review</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?positiveReviewCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">name</span> <span class="nv">?name</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">datePublished</span> <span class="nv">?datePublished</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">recipeCategory</span> <span class="nv">?category</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">image</span> <span class="nv">?image</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">keywords</span> <span class="nv">?keyword</span> <span class="p">.</span>
#
#   <span class="c"># 1) Must
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recipe</th>
#       <th>name</th>
#       <th>datePublished</th>
#       <th>calories</th>
#       <th>image</th>
#       <th>positiveReviewCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/recipe_8670</td>
#       <td>indian rice pudding</td>
#       <td>2001-03-26T10:30:00+00:00</td>
#       <td>198.0</td>
#       <td>character(0)</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 6. Identify the top 10 highly-rated beverages, including their preparation time and sugar content.

# %%
run_query(g, 'q6.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2024 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">ex</span><span class="p">:</span>   <span class="nl">&lt;http://kg-course/food-nutrition/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">sdo</span><span class="p">:</span>  <span class="nl">&lt;https://schema.org/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdfs</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/2000/01/rdf-schema#&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">xsd</span><span class="p">:</span>  <span class="nl">&lt;http://www.w3.org/2001/XMLSchema#&gt;</span>
#
# <span class="k">SELECT</span>
#   <span class="nv">?recipe</span>
#   <span class="nv">?name</span>
#   <span class="nv">?prepTime</span>
#   <span class="nv">?sugarContent</span>
#   <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?review</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?positiveReviewCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="k">a</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">recipeCategory</span> <span class="nv">?category</span> <span class="p">;</span>
#           <span class="nn">sdo</span><span class="p">:</span><span class="nt">name</span> <span class="nv">?name</span> <span class="p">.</span>
#
#   <span class="c"># Must be a beverage (case-insensitive match)</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nv">?category</span><span class="p">),</span> <span class="s">&quot;beverage&quot;</span><span class="p">))</span>
#
#   <span class="c"># OPTIONAL so we don&#39;t fail if prepTime is missing</span>
#   <span class="k">OPTIONAL</span> <span class="p">{</span> <span class="nv">?recipe</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">prepTime</span> <span class="nv">?prepTime</span> <span class="p">}</span>
#
#   <span class="c"># Retrieve sugar content from a NutritionInfo node</span>
#   <span class="nv">?dish</span> <span class="nn">ex</span><span class="p">:</span><span class="nt">hasRecipe</span> <span class="nv">?recipe</span> <span class="p">;</span>
#         <span class="nn">ex</span><span class="p">:</span><span class="nt">nutrition</span> <span class="nv">?nutri</span> <span class="p">.</span>
#   <span class="nv">?nutri</span> <span class="nn">sdo</span><span class="p">:</span><span class="nt">sugarContent</span> <span class="nv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recipe</th>
#       <th>name</th>
#       <th>prepTime</th>
#       <th>sugarContent</th>
#       <th>positiveReviewCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/recipe_2942</td>
#       <td>strawberry punch #1</td>
#       <td>P0D</td>
#       <td>10.1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://kg-course/food-nutrition/recipe_2637</td>
#       <td>summer citrus punch</td>
#       <td>PT10M</td>
#       <td>21.7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://kg-course/food-nutrition/recipe_129</td>
#       <td>champagne punch</td>
#       <td>PT5M</td>
#       <td>38.1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://kg-course/food-nutrition/recipe_4244</td>
#       <td>frosted margaritas</td>
#       <td>P0D</td>
#       <td>15.2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://kg-course/food-nutrition/recipe_2940</td>
#       <td>lemon sherbet punch</td>
#       <td>PT10M</td>
#       <td>4.4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://kg-course/food-nutrition/recipe_5315</td>
#       <td>icy holiday punch</td>
#       <td>P1D</td>
#       <td>12.7</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 7. Identify the highest-rated recipes containing protein-rich ingredients and check if their corresponding cuisines are commonly available in the USA restaurants.

# %%
run_query(g, 'q7.rq')
# Out:
# No file for q7.rq

# %% [markdown]
# 8. Find the top 5 healthiest recipes based on a nutrition density score (NDS), along with their average sentiment from reviews. Check if restaurants serve cuisines linked to these recipes and retrieve their aggregate restaurant ratings.

# %%
run_query(g, 'q8.rq')
# Out:
# No file for q8.rq
