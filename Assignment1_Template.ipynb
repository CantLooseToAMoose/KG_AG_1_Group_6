# %% [markdown]
# # 📘 KG course SPARQL notebook
#
# A notebook to run SPARQL queries for the KG course at UM DACS.
#
# 1. Update the `g.parse()` calls in the first cell to import your RDF files.
# 2. In the same folder as the notebook create files with your SPARQL queries (e.g. `q1.rq`), and execute them with `run_query(g, 'q1.rq')`
#
# Use the `.rq` file extension to get SPARQL syntax coloration

# %%
import sys
# !{sys.executable} -m pip install pandas oxrdflib Pygments

import pandas as pd
from IPython.display import display, HTML
from pygments import highlight
from pygments.lexers import SparqlLexer
from pygments.formatters import HtmlFormatter
from rdflib import Graph

def run_query(graph, query_path):
    try:
        with open(query_path, 'r') as file:
            query = file.read()
    except Exception as _e:
        print(f"No file for {query_path}")
        return
    results = graph.query(query)
    # Display the SPARQL query
    formatted_query = highlight(query, SparqlLexer(), HtmlFormatter(style='solarized-dark', full=True, nobackground=True))
    display(HTML(formatted_query))
    # Convert results to a Pandas DataFrame
    res_list = []
    for row in results:
        res_list.append([str(item) for item in row])
    df = pd.DataFrame(res_list, columns=[str(var) for var in results.vars]) if len(res_list) > 0 else pd.DataFrame()
    # Display the DataFrame as a table in Jupyter Notebook
    display(HTML(df.to_html()))

g = Graph(store="Oxigraph")

# TODO: modify/add paths to your RDF files
g.parse("./climate_kg_ontology.ttl")
# g.parse("./climate_kg.ttl")

print(f"Working with {len(g)} triples")
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (2.0.3)
# Collecting oxrdflib
#   Downloading oxrdflib-0.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Pygments in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (2.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.25.1)
# Collecting pyoxigraph~=0.4.2 (from oxrdflib)
#   Downloading pyoxigraph-0.4.7-cp38-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: rdflib<8.0,>=6.3 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from oxrdflib) (7.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\jpereira01\appdata\local\programs\python\python311\lib\site-packages (from rdflib<8.0,>=6.3->oxrdflib) (3.2.1)
# Downloading oxrdflib-0.4.0-py3-none-any.whl (10 kB)
# Downloading pyoxigraph-0.4.7-cp38-abi3-win_amd64.whl (4.8 MB)
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.8/4.8 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.8/4.8 MB 13.8 MB/s eta 0:00:00
# Installing collected packages: pyoxigraph, oxrdflib
# Successfully installed oxrdflib-0.4.0 pyoxigraph-0.4.7
# Working with 80 triples

# %% [markdown]
# 1. Find recipes that are risky for individuals allergic to mango.

# %%
g.parse("./vocabulary.ttl", format="turtle")
print(len(g))
print(f"Graph size: {len(g)}")
# Out:
#   Cell In[8], line 4
#     SELECT ?recipe ?ingredient
#            ^
# SyntaxError: invalid syntax

# %%
run_query(g, 'q1.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?s</span> <span class="nv">?p</span> <span class="nv">?o</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?s</span> <span class="nv">?p</span> <span class="nv">?o</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">LIMIT</span> <span class="mi">100</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>s</th>
#       <th>p</th>
#       <th>o</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/2004/02/skos/core#closeMatch</td>
#       <td>https://schema.org/reviewCount</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#integer</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>https://schema.org/Restaurant</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>Amount of reviews received</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>votes</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://kg-course/food-nutrition/votes</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>http://kg-course/food-nutrition/switchToOrderMenu</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#boolean</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>http://kg-course/food-nutrition/switchToOrderMenu</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>https://schema.org/Restaurant</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://kg-course/food-nutrition/switchToOrderMenu</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>The availibility to have the ability to switch to the order menu.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>http://kg-course/food-nutrition/switchToOrderMenu</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>switchToOrderMenu</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>http://kg-course/food-nutrition/switchToOrderMenu</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>http://kg-course/food-nutrition/sentiment</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#string</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>http://kg-course/food-nutrition/sentiment</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>http://kg-course/food-nutrition/Review</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>http://kg-course/food-nutrition/sentiment</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>The sentiment (positive, neutral, negative) of the review.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>http://kg-course/food-nutrition/sentiment</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>sentiment</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>http://kg-course/food-nutrition/sentiment</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>http://kg-course/food-nutrition/reviewText</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#string</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>http://kg-course/food-nutrition/reviewText</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>http://kg-course/food-nutrition/Review</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>http://kg-course/food-nutrition/reviewText</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>The text of the review.</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>http://kg-course/food-nutrition/reviewText</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>reviewText</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>http://kg-course/food-nutrition/reviewText</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/2004/02/skos/core#closeMatch</td>
#       <td>https://schema.org/nutrition</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://kg-course/food-nutrition/NutritionInfo</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>http://kg-course/food-nutrition/Dish</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>Links a dish to its nutrition info.</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>nutrition</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>http://kg-course/food-nutrition/nutrition</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>http://kg-course/food-nutrition/numberOfDishes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#integer</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>http://kg-course/food-nutrition/numberOfDishes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>https://schema.org/Restaurant</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>http://kg-course/food-nutrition/numberOfDishes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>Amount of unque dishes served by a restaurant.</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>http://kg-course/food-nutrition/numberOfDishes</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>numberOfDishes</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>http://kg-course/food-nutrition/numberOfDishes</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>http://kg-course/food-nutrition/isDeliveringNow</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#range</td>
#       <td>http://www.w3.org/2001/XMLSchema#boolean</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>http://kg-course/food-nutrition/isDeliveringNow</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#domain</td>
#       <td>https://schema.org/Restaurant</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>http://kg-course/food-nutrition/isDeliveringNow</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#comment</td>
#       <td>Links a restaurant to the fact if its delivering now.</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>http://kg-course/food-nutrition/isDeliveringNow</td>
#       <td>http://www.w3.org/2000/01/rdf-schema#label</td>
#       <td>isDeliveringNow</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>http://kg-course/food-nutrition/isDeliveringNow</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td>
#       <td>http://www.w3.org/1999/02/22-rdf-syntax-ns#Property</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>http://kg-course/food-nutrition/inCountry</td>
#       <td>http://www.w3.org/2004/02/skos/core#closeMatch</td>
#       <td>https:

# %% [markdown]
# 2. List all pies tagged as 'healthy' with a total cooking time of less than 2 hours.

# %%
run_query(g, 'q2.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">schema</span><span class="p">:</span> <span class="nl">&lt;https://schema.org/&gt;</span>
#
# <span class="k">SELECT</span> <span class="nv">?recipe</span> <span class="nv">?name</span> <span class="nv">?cookTime</span> <span class="nv">?prepTime</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="k">a</span> <span class="nn">schema</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">;</span>
#           <span class="nn">schema</span><span class="p">:</span><span class="nt">name</span> <span class="nv">?name</span> <span class="p">;</span>
#           <span class="nn">schema</span><span class="p">:</span><span class="nt">recipeCategory</span> <span class="nv">?category</span> <span class="p">;</span>
#           <span class="nn">schema</span><span class="p">:</span><span class="nt">keywords</span> <span class="nv">?keywords</span> <span class="p">;</span>
#           <span class="nn">schema</span><span class="p">:</span><span class="nt">cookTime</span> <span class="nv">?cookTime</span> <span class="p">;</span>
#           <span class="nn">schema</span><span class="p">:</span><span class="nt">prepTime</span> <span class="nv">?prepTime</span> <span class="p">.</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nf">STR</span><span class="p">(</span><span class="nv">?category</span><span class="p">)),</span> <span class="s">&quot;pie&quot;</span><span class="p">))</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nf">CONTAINS</span><span class="p">(</span><span class="nf">LCASE</span><span class="p">(</span><span class="nf">STR</span><span class="p">(</span><span class="nv">?keywords</span><span class="p">)),</span> <span class="s">&quot;healthy&quot;</span><span class="p">))</span>
#   <span class="k">FILTER</span><span class="p">((</span><span class="nv">?cookTime</span> <span class="o">+</span> <span class="nv">?prepTime</span><span class="p">)</span> <span class="o">&lt;</span> <span class="mi">120</span><span class="p">)</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# 3. List all restaurants in New Delhi that serve Chinese cuisine and offer online delivery.

# %%
run_query(g, 'q3.rq')
# Out:
# No file for q3.rq

# %% [markdown]
# 4. Find the average cost of two dining at restaurants in Davenport that serve Asian food.

# %%
run_query(g, 'q4.rq')
# Out:
# No file for q4.rq

# %% [markdown]
# 5. Recommend the top 5 desserts published after 2000 that are labeled as ‘Easy’ and low in calories, along with their images.

# %%
run_query(g, 'q5.rq')
# Out:
# No file for q5.rq

# %% [markdown]
# 6. Identify the top 10 highly-rated beverages, including their preparation time and sugar content.

# %%
run_query(g, 'q6.rq')
# Out:
# No file for q6.rq

# %% [markdown]
# 7. Identify the highest-rated recipes containing protein-rich ingredients and check if their corresponding cuisines are commonly available in the USA restaurants.

# %%
run_query(g, 'q7.rq')
# Out:
# No file for q7.rq

# %% [markdown]
# 8. Find the top 5 healthiest recipes based on a nutrition density score (NDS), along with their average sentiment from reviews. Check if restaurants serve cuisines linked to these recipes and retrieve their aggregate restaurant ratings.

# %%
run_query(g, 'q8.rq')
# Out:
# No file for q8.rq
